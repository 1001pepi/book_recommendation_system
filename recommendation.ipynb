# %% [markdown]
# ## Build recommendation system

# %% [markdown]
# In this book we are going to build the recommendation system.
#
# Achieving this will require two steps:
#
# + Find the users who like the same books as us
# + Find the other books those users like since will probably like the same books.

# %%
#list of liked books
liked_books = ["681495", "380748", "1062354", "638824", "12"]

# %% [markdown]
# ## Explore book rating data

# %% [markdown]
# Look at some lines of hte `book_id_map.csv` file. This file is available at [this URL](https://www.youtube.com/redirect?event=video_description&redir_token=QUFFLUhqbHcyMzFtQ0N3dUhDcXBtUVEzak8yOWdVRUFjQXxBQ3Jtc0ttQTBpMWRUTS0zT2xJNk14VDM3T0pVSFJxOFNIazBJZU1sS2NWNzJFVGt3VXlYZDFCNkpYSm1GaDVyVlpnbU5JTllZaGhObXlYRGt6bFZoZS1ZWEl6NEZqcVhkMFlHUGs1bngtQjhyeFFRTDFNMlRZSQ&q=https%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1CHTAaNwyzvbi1TR08MJrJ03BxA266Yxr&v=x-alwfgQ-cY).
#
# We first have to navigate to the directoray containing the csv file.

# %%
project_directory = "/content/drive/MyDrive/Colab Notebooks/book_recommandation_system"

# %%
cd '{project_directory}'
# Out:
# /content/drive/MyDrive/Colab Notebooks/book_recommandation_system

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %% [markdown]
# Read the content of the file in a stream fashion.

# %%
csv_book_mapping = {}

with open('book_id_map.csv', 'r') as f:
  while True:
    line = f.readline()
    if not line:
      break
    csv_id, book_id = line.strip().split(",")
    csv_book_mapping[csv_id] = book_id

# %%
len(csv_book_mapping)
# Out:
# 2360651

# %% [markdown]
# ### Download the interaction data set

# %%
cd /content
# Out:
# /content

# %%
# !gdown 1zmylV7XW2dfQVCLeg1LbllfQtHD2KUon
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zmylV7XW2dfQVCLeg1LbllfQtHD2KUon
# To: /content/goodreads_interactions.csv
# 100% 4.32G/4.32G [00:21<00:00, 199MB/s]

# %% [markdown]
# Number of lines of the interactions file

# %%
# !wc -l goodreads_interactions.csv
# Out:
# 228648343 goodreads_interactions.csv

# %% [markdown]
# Look at the size of the interactions file

# %%
# !ls -lh | grep goodreads_interactions.csv
# Out:
# -rw-r--r-- 1 root root 4.1G Sep 25 19:36 goodreads_interactions.csv

# %% [markdown]
# ### Finding the users who like the same books as us

# %% [markdown]
# Look at some lines of the interactions file.

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %%
overlap_users = set()

with open("goodreads_interactions.csv", 'r') as f:
  while True:
    line = f.readline()
    if not line:
      break
    user_id, csv_id, _, rating, _ = line.split(",")
    
    if user_id in overlap_users:
      continue
    
    try:
      rating = int(rating)
    except:
      continue

    book_id =  csv_book_mapping[csv_id]

    if book_id in liked_books and rating  >= 4:
      overlap_users.add(user_id)

# %%
len(overlap_users)
# Out:
# 342

# %% [markdown]
# ### Find what books those users liked

# %%
rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
  while True:
    line = f.readline()
    if not line:
      break
    user_id, csv_id, _, rating, _ = line.split(",")
    
    if user_id in overlap_users:
      book_id =  csv_book_mapping[csv_id]
      rec_lines.append([user_id, book_id, rating])

# %%
import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %% [markdown]
# Look at the top recommendations

# %%
top_recs = recs["book_id"].value_counts().head(10)
top_recs = top_recs.index.values

# %%
cd '{project_directory}'
# Out:
# /content/drive/MyDrive/Colab Notebooks/book_recommandation_system

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %% [markdown]
# ### Create initial book recommendations

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#         book_id                                              title  ratings  \
# 446972     5907                                         The Hobbit  2099680
# 463463     4671                                   The Great Gatsby  2758812
# 477321        1  Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 615314     5470                                               1984  2023937
# 878545        3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 902688   136251  Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 995137    15881  Harry Potter and the Chamber of Secrets (Harry...  1821802
# 1155584       2  Harry Potter and the Order of the Phoenix (Har...  1766895
# 1221893      12  The Ultimate Hitchhiker's Guide: Five Complete...     3471
# 1248586       6  Harry Potter and the Goblet of Fire (Harry Pot...  1792561
#
#                                                        url  \
# 446972   https://www.goodreads.com/book/show/5907.The_H...
# 463463   https://www.goodreads.com/book/show/4671.The_G...
# 477321   https://www.goodreads.com/book/show/1.Harry_Po...
# 615314       https://www.goodreads.com/book/show/5470.1984
# 878545   https://www.goodreads.com/book/show/3.Harry_Po...
# 902688   https://www.goodreads.com/book/show/136251.Har...
# 995137   https://www.goodreads.com/book/show/15881.Harr...
# 1155584  https://www.goodreads.com/book/show/2.Harry_Po...
# 1221893  https://www.goodreads.com/book/show/12.The_Ult...
# 1248586  https://www.goodreads.com/book/show/6.Harry_Po...
#
#                                                cover_image  \
# 446972   https://images.gr-assets.com/books/1372847500m...
# 463463   https://images.gr-assets.com/books/1490528560m...
# 477321   https://images.gr-assets.com/books/1361039191m...
# 615314   https://images.gr-assets.com/books/1348990566m...
# 878545   https://images.gr-assets.com/books/1474154022m...
# 902688   https://images.gr-assets.com/books/1474171184m...
# 995137   https://images.gr-assets.com/books/1474169725m...
# 1155584  https://images.gr-assets.com/books/1507396732m...
# 1221893  https://images.gr-assets.com/books/1404658218m...
# 1248586  https://images.gr-assets.com/books/1361482611m...
#
#                                                  mod_title
# 446972                                          the hobbit
# 463463                                    the great gatsby
# 477321   harry potter and the halfblood prince harry po...
# 615314                                                1984
# 878545   harry potter and the sorcerers stone harry pot...
# 902688   harry potter and the deathly hallows harry pot...
# 995137   harry potter and the chamber of secrets harry ...
# 1155584  harry potter and the order of the phoenix harr...
# 1221893  the ultimate hitchhikers guide five complete n...
# 1248586  harry potter and the goblet of fire harry pott...

# %% [markdown]
# ### Improving our book recommendations

# %% [markdown]
# Our recommendation system takes into consideration only how popular a book is. Thus it recommends books that anyone may like, not books that are somehow related to the list of our liked books. To correct this, we have to make sure that the recommended books are only popular among the users that well rated the books we liked, and not popular among all the users.

# %%
all_recs = recs["book_id"].value_counts()
all_recs = all_recs.to_frame().reset_index()

# %%
all_recs.head(2)
# Out:
#   index  book_id
# 0    12      342
# 1     3      215

# %%
#rename our columns
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs.head(2)
# Out:
#   book_id  book_count
# 0      12         342
# 1       3         215

# %%
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_recs
# Out:
#          book_id  book_count  \
# 0             12         342
# 1              3         215
# 2           5470         205
# 3           4671         201
# 4         136251         194
# ...          ...         ...
# 140880  18730738           1
# 140881  20878116           1
# 140882  18731053           1
# 140883  20622800           1
# 140884  17620155           1
#
#                                                     title  ratings  \
# 0       The Ultimate Hitchhiker's Guide: Five Complete...     3471
# 1       Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 2                                                    1984  2023937
# 3                                        The Great Gatsby  2758812
# 4       Harry Potter and the Deathly Hallows (Harry Po...  1784684
# ...                                                   ...      ...
# 140880                        The Cheat Code for God Mode       42
# 140881         The Atlantis Gene (The Origin Mystery, #1)      153
# 140882        Inspector Hobbes and the Curse (Unhuman #2)      117
# 140883               Gargoyle Knight (Gargoyle Knight #1)      107
# 140884     When The Bough Breaks (The Empire's Corps, #3)      639
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/12.The_Ult...
# 1       https://www.goodreads.com/book/show/3.Harry_Po...
# 2           https://www.goodreads.com/book/show/5470.1984
# 3       https://www.goodreads.com/book/show/4671.The_G...
# 4       https://www.goodreads.com/book/show/136251.Har...
# ...                                                   ...
# 140880  https://www.goodreads.com/book/show/18730738-t...
# 140881  https://www.goodreads.com/book/show/20878116-t...
# 140882  https://www.goodreads.com/book/show/18731053-i...
# 140883  https://www.goodreads.com/book/show/20622800-g...
# 140884  https://www.goodreads.com/book/show/17620155-w...
#
#                                               cover_image  \
# 0       https://images.gr-assets.com/books/1404658218m...
# 1       https://images.gr-assets.com/books/1474154022m...
# 2       https://images.gr-assets.com/books/1348990566m...
# 3       https://images.gr-assets.com/books/1490528560m...
# 4       https://images.gr-assets.com/books/1474171184m...
# ...                                                   ...
# 140880  https://images.gr-assets.com/books/1382998378m...
# 140881  https://images.gr-assets.com/books/1392938677m...
# 140882  https://images.gr-assets.com/books/1383409930m...
# 140883  https://images.gr-assets.com/books/1390496626m...
# 140884  https://images.gr-assets.com/books/1369360309m...
#
#                                                 mod_title
# 0       the ultimate hitchhikers guide five complete n...
# 1       harry potter and the sorcerers stone harry pot...
# 2                                                    1984
# 3                                        the great gatsby
# 4       harry potter and the deathly hallows harry pot...
# ...                                                   ...
# 140880                        the cheat code for god mode
# 140881             the atlantis gene the origin mystery 1
# 140882           inspector hobbes and the curse unhuman 2
# 140883                  gargoyle knight gargoyle knight 1
# 140884          when the bough breaks the empires corps 3
#
# [140885 rows x 7 columns]

# %% [markdown]
# Now we are going to create a score that we will use to rank the recommendations. This score should penalyse books popular among all users, and reward books that are only popular within the users that read the books I liked.

# %%
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#         book_id  book_count  \
# 0            12         342
# 9185   10085735           5
# 10384  15999003           5
# 7681    9531458           6
# 11150  11049978           4
# 20087  23244609           3
# 21475   2837684           3
# 22783  11525109           3
# 13495  34386617           4
# 16896    442480           3
#
#                                                    title  ratings  \
# 0      The Ultimate Hitchhiker's Guide: Five Complete...     3471
# 9185                                  Ebon (Pegasus, #2)       34
# 10384          Inherit the Night (Gentleman Bastard, #7)       36
# 7681   7 Things To Do Before You Die in Talgarth (Sha...       61
# 11150   The Last Great Tortoise Race (Nursery Crime, #3)       28
# 20087                    Tricks for Free (InCryptid, #7)       16
# 21475                                  The Levitationist       20
# 22783  The Pioneer Cookbook: Recipes for Today's Kitchen       21
# 13495                   The Night Masquerade (Binti, #3)       38
# 16896                       King Arthur: Hero and Legend       22
#
#                                                      url  \
# 0      https://www.goodreads.com/book/show/12.The_Ult...
# 9185   https://www.goodreads.com/book/show/10085735-ebon
# 10384  https://www.goodreads.com/book/show/15999003-i...
# 7681   https://www.goodreads.com/book/show/9531458-7-...
# 11150  https://www.goodreads.com/book/show/11049978-t...
# 20087  https://www.goodreads.com/book/show/23244609-t...
# 21475  https://www.goodreads.com/book/show/2837684-th...
# 22783  https://www.goodreads.com/book/show/11525109-t...
# 13495  https://www.goodreads.com/book/show/34386617-t...
# 16896  https://www.goodreads.com/book/show/442480.Kin...
#
#                                              cover_image  \
# 0      https://images.gr-assets.com/books/1404658218m...
# 9185   https://s.gr-assets.com/assets/nophoto/book/11...
# 10384  https://s.gr-assets.com/assets/nophoto/book/11...
# 7681   https://s.gr-assets.com/assets/nophoto/book/11...
# 11150  https://s.gr-assets.com/assets/nophoto/book/11...
# 20087  https://images.gr-assets.com/books/1499885246m...
# 21475  https://s.gr-assets.com/assets/nophoto/book/11...
# 22783  https://images.gr-assets.com/books/1337188080m...
# 13495  https://images.gr-assets.com/books/1495725402m...
# 16896  https://images.gr-assets.com/books/1368429800m...
#
#                                                mod_title      score
# 0      the ultimate hitchhikers guide five complete n...  33.697494
# 9185                                      ebon pegasus 2   0.735294
# 10384              inherit the night gentleman bastard 7   0.694444
# 7681   7 things to do before you die in talgarth shad...   0.590164
# 11150       the last great tortoise race nursery crime 3   0.571429
# 20087                        tricks for free incryptid 7   0.562500
# 21475                                  the levitationist   0.450000
# 22783    the pioneer cookbook recipes for todays kitchen   0.428571
# 13495                       the night masquerade binti 3   0.421053
# 16896                        king arthur hero and legend   0.409091

# %% [markdown]
# We can notice that some of the resulting books have a low number of ratings. We are going to remove those books.

# %%
popular_recs = all_recs[all_recs["book_count"] > 75].sort_values("score", ascending=False)

# %%
def make_clickable(val):
  #This function will help us to style links in dataframes such that we can click on them to see if a book is the
  #one we are looking for
  return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
  return '<img src="{}" width=50></img>'.format(val)

#avoid recommending books we have already read
popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url':make_clickable, 'cover_image':show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_cabc4_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >book_count</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >ratings</th>
#       <th class="col_heading level0 col4" >url</th>
#       <th class="col_heading level0 col5" >cover_image</th>
#       <th class="col_heading level0 col6" >mod_title</th>
#       <th class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cabc4_level0_row0" class="row_heading level0 row0" >103</th>
#       <td id="T_cabc4_row0_col0" class="data row0 col0" >357</td>
#       <td id="T_cabc4_row0_col1" class="data row0 col1" >79</td>
#       <td id="T_cabc4_row0_col2" class="data row0 col2" >The Long Dark Tea-Time of the Soul (Dirk Gently, #2)</td>
#       <td id="T_cabc4_row0_col3" class="data row0 col3" >60364</td>
#       <td id="T_cabc4_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/357.The_Long_Dark_Tea_Time_of_the_Soul">Goodreads</a></td>
#       <td id="T_cabc4_row0_col5" class="data row0 col5" ><img src="https://images.gr-assets.com/books/1388257271m/357.jpg" width=50></img></td>
#       <td id="T_cabc4_row0_col6" class="data row0 col6" >the long dark teatime of the soul dirk gently 2</td>
#       <td id="T_cabc4_row0_col7" class="data row0 col7" >0.103389</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row1" class="row_heading level0 row1" >80</th>
#       <td id="T_cabc4_row1_col0" class="data row1 col0" >365</td>
#       <td id="T_cabc4_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_cabc4_row1_col2" class="data row1 col2" >Dirk Gently's Holistic Detective Agency (Dirk Gently #1)</td>
#       <td id="T_cabc4_row1_col3" class="data row1 col3" >91027</td>
#       <td id="T_cabc4_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/365.Dirk_Gently_s_Holistic_Detective_Agency">Goodreads</a></td>
#       <td id="T_cabc4_row1_col5" class="data row1 col5" ><img src="https://images.gr-assets.com/books/1404697381m/365.jpg" width=50></img></td>
#       <td id="T_cabc4_row1_col6" class="data row1 col6" >dirk gentlys holistic detective agency dirk gently 1</td>
#       <td id="T_cabc4_row1_col7" class="data row1 col7" >0.083151</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row2" class="row_heading level0 row2" >63</th>
#       <td id="T_cabc4_row2_col0" class="data row2 col0" >2744</td>
#       <td id="T_cabc4_row2_col1" class="data row2 col1" >96</td>
#       <td id="T_cabc4_row2_col2" class="data row2 col2" >Anansi Boys</td>
#       <td id="T_cabc4_row2_col3" class="data row2 col3" >140090</td>
#       <td id="T_cabc4_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/2744.Anansi_Boys">Goodreads</a></td>
#       <td id="T_cabc4_row2_col5" class="data row2 col5" ><img src="https://images.gr-assets.com/books/1479778049m/2744.jpg" width=50></img></td>
#       <td id="T_cabc4_row2_col6" class="data row2 col6" >anansi boys</td>
#       <td id="T_cabc4_row2_col7" class="data row2 col7" >0.065786</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row3" class="row_heading level0 row3" >41</th>
#       <td id="T_cabc4_row3_col0" class="data row3 col0" >7082</td>
#       <td id="T_cabc4_row3_col1" class="data row3 col1" >113</td>
#       <td id="T_cabc4_row3_col2" class="data row3 col2" >Do Androids Dream of Electric Sheep?</td>
#       <td id="T_cabc4_row3_col3" class="data row3 col3" >229370</td>
#       <td id="T_cabc4_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/7082.Do_Androids_Dream_of_Electric_Sheep_">Goodreads</a></td>
#       <td id="T_cabc4_row3_col5" class="data row3 col5" ><img src="https://images.gr-assets.com/books/1435458683m/7082.jpg" width=50></img></td>
#       <td id="T_cabc4_row3_col6" class="data row3 col6" >do androids dream of electric sheep</td>
#       <td id="T_cabc4_row3_col7" class="data row3 col7" >0.055670</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row4" class="row_heading level0 row4" >28</th>
#       <td id="T_cabc4_row4_col0" class="data row4 col0" >12067</td>
#       <td id="T_cabc4_row4_col1" class="data row4 col1" >127</td>
#       <td id="T_cabc4_row4_col2" class="data row4 col2" >Good Omens: The Nice and Accurate Prophecies of Agnes Nutter, Witch</td>
#       <td id="T_cabc4_row4_col3" class="data row4 col3" >307430</td>
#       <td id="T_cabc4_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/12067.Good_Omens">Goodreads</a></td>
#       <td id="T_cabc4_row4_col5" class="data row4 col5" ><img src="https://images.gr-assets.com/books/1392528568m/12067.jpg" width=50></img></td>
#       <td id="T_cabc4_row4_col6" class="data row4 col6" >good omens the nice and accurate prophecies of agnes nutter witch</td>
#       <td id="T_cabc4_row4_col7" class="data row4 col7" >0.052464</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row5" class="row_heading level0 row5" >61</th>
#       <td id="T_cabc4_row5_col0" class="data row5 col0" >830</td>
#       <td id="T_cabc4_row5_col1" class="data row5 col1" >96</td>
#       <td id="T_cabc4_row5_col2" class="data row5 col2" >Snow Crash</td>
#       <td id="T_cabc4_row5_col3" class="data row5 col3" >179029</td>
#       <td id="T_cabc4_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/830.Snow_Crash">Goodreads</a></td>
#       <td id="T_cabc4_row5_col5" class="data row5 col5" ><img src="https://images.gr-assets.com/books/1477624625m/830.jpg" width=50></img></td>
#       <td id="T_cabc4_row5_col6" class="data row5 col6" >snow crash</td>
#       <td id="T_cabc4_row5_col7" class="data row5 col7" >0.051478</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row6" class="row_heading level0 row6" >33</th>
#       <td id="T_cabc4_row6_col0" class="data row6 col0" >14497</td>
#       <td id="T_cabc4_row6_col1" class="data row6 col1" >119</td>
#       <td id="T_cabc4_row6_col2" class="data row6 col2" >Neverwhere</td>
#       <td id="T_cabc4_row6_col3" class="data row6 col3" >275822</td>
#       <td id="T_cabc4_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/14497.Neverwhere">Goodreads</a></td>
#       <td id="T_cabc4_row6_col5" class="data row6 col5" ><img src="https://images.gr-assets.com/books/1348747943m/14497.jpg" width=50></img></td>
#       <td id="T_cabc4_row6_col6" class="data row6 col6" >neverwhere</td>
#       <td id="T_cabc4_row6_col7" class="data row6 col7" >0.051341</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row7" class="row_heading level0 row7" >62</th>
#       <td id="T_cabc4_row7_col0" class="data row7 col0" >22328</td>
#       <td id="T_cabc4_row7_col1" class="data row7 col1" >96</td>
#       <td id="T_cabc4_row7_col2" class="data row7 col2" >Neuromancer (Sprawl, #1)</td>
#       <td id="T_cabc4_row7_col3" class="data row7 col3" >184611</td>
#       <td id="T_cabc4_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/22328.Neuromancer">Goodreads</a></td>
#       <td id="T_cabc4_row7_col5" class="data row7 col5" ><img src="https://images.gr-assets.com/books/1167348726m/22328.jpg" width=50></img></td>
#       <td id="T_cabc4_row7_col6" class="data row7 col6" >neuromancer sprawl 1</td>
#       <td id="T_cabc4_row7_col7" class="data row7 col7" >0.049921</td>
#     </tr>
#     <tr>
#       <th id="T_cabc4_level0_row8" class="row_heading level0 row8" >24</th>
#       <td id="T_cabc4_row8_col0" class="data row8 col0" >472331</td>
#       <td id="T_cabc4_row8_col1" class="data row8 col1" >139</td>
#       <td id="T_cabc4_row8_col2" class="data row8 col2" >Watchmen</td>
#       <td id="T_cabc4_row8_col3" class="data row8 col3" >406669</td>
#       <td id="T_cabc4_row8_col4" class="data row8 col4" ><a target="_blank" href="https:/
